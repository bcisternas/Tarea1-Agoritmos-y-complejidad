# %%
import pandas as pd
import matplotlib.pyplot as plt

data_aleatorio = pd.read_csv('Datasets_Resultados/tiempos_aleatorio.csv')

# Crear las curvas teóricas n^2 y n log n
n = np.array(tamanios)
n_squared = n ** 2
n_log_n = n * np.log2(n)


plt.figure(figsize=(10,6))
plt.plot(data_aleatorio['Tamaño'], data_aleatorio['Selection Sort'], label='Selection Sort', marker='o')
plt.plot(data_aleatorio['Tamaño'], data_aleatorio['Merge Sort'], label='Merge Sort', marker='o')
plt.plot(data_aleatorio['Tamaño'], data_aleatorio['Quick Sort'], label='Quick Sort', marker='o')
plt.plot(data_aleatorio['Tamaño'], data_aleatorio['std::sort'], label='std::sort', marker='o')

# Graficar las curvas teóricas
plt.plot(n, n_squared / max(n_squared) * max(selection_sort), label='$n^2$', linestyle='--', color='purple')
plt.plot(n, n_log_n / max(n_log_n) * max(merge_sort), label='$n \log n$', linestyle='--', color='pink')

plt.title('Comparación de Algoritmos de Ordenamiento - Dataset Aleatorio')
plt.xlabel('Tamaño del Dataset')
plt.ylabel('Tiempo de Ejecución (ms)')
plt.ylim([0, 10000])    #Cambiar limites del eje y
plt.legend()
plt.grid(True)

plt.savefig('graficos\orden_dat_aleatorios.png')

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


# Leer el archivo CSV
df = pd.read_csv('Datasets_Resultados/tiempos_casi_ordenado.csv')

# Mostrar las primeras filas del DataFrame para verificar que los datos se leyeron correctamente
print(df.head())

# Extraer los datos del CSV
tamanios = df['Tamaño']
selection_sort = df['Selection Sort']
merge_sort = df['Merge Sort']
quick_sort = df['Quick Sort']
std_sort = df['std::sort']

# Crear las curvas teóricas n^2 y n log n
n = np.array(tamanios)
n_squared = n ** 2
n_log_n = n * np.log2(n)

# Crear el gráfico
plt.figure(figsize=(10, 6))
plt.plot(tamanios, selection_sort, label='Selection Sort', marker='o')
plt.plot(tamanios, merge_sort, label='Merge Sort', marker='o')
plt.plot(tamanios, quick_sort, label='Quick Sort', marker='o')
plt.plot(tamanios, std_sort, label='std::sort', marker='o')

# Graficar las curvas teóricas
plt.plot(n, n_squared / max(n_squared) * max(selection_sort), label='$n^2$', linestyle='--', color='purple')
plt.plot(n, n_log_n / max(n_log_n) * max(merge_sort), label='$n \log n$', linestyle='--', color='pink')


# Configuración del gráfico
plt.title('Comparación de Algoritmos de Ordenamiento con datos casi ordenado')
plt.xlabel('Tamaño del Dataset')
plt.ylabel('Tiempo de Ejecución (ms)')
plt.ylim([0, 10000])    #Cambiar limites del eje y
plt.legend()
plt.grid(True)

plt.savefig('graficos\orden_dat_casi_ord.png')

# Mostrar el gráfico
plt.show()
# Out:
#    Tamaño  Selection Sort  Merge Sort  Quick Sort  std::sort
# 0   10000              41           2           7          1
# 1  100000            4413          36          75         15
# 2  200000           17704          61         158         30
# 3  300000           40013          93         234         52
# 4  400000           71245         125         322         64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Leer el archivo CSV
df = pd.read_csv('Datasets_Resultados/tiempos_inversamente_ordenado.csv')

# Mostrar las primeras filas del DataFrame para verificar que los datos se leyeron correctamente
print(df.head())

# Extraer los datos del CSV
tamanios = df['Tamaño']
selection_sort = df['Selection Sort']
merge_sort = df['Merge Sort']
quick_sort = df['Quick Sort']
std_sort = df['std::sort']

# Crear las curvas teóricas n^2 y n log n
n = np.array(tamanios)
n_squared = n ** 2
n_log_n = n * np.log2(n)

# Crear el gráfico
plt.figure(figsize=(10, 6))
plt.plot(tamanios, selection_sort, label='Selection Sort', marker='o')
plt.plot(tamanios, merge_sort, label='Merge Sort', marker='o')
plt.plot(tamanios, quick_sort, label='Quick Sort', marker='o')
plt.plot(tamanios, std_sort, label='std::sort', marker='o')

# Graficar las curvas teóricas
plt.plot(n, n_squared / max(n_squared) * max(selection_sort), label='$n^2$', linestyle='--', color='purple')
plt.plot(n, n_log_n / max(n_log_n) * max(merge_sort), label='$n \log n$', linestyle='--', color='pink')


# Configuración del gráfico
plt.title('Comparación de Algoritmos de Ordenamiento con datos inversamente ordenado')
plt.xlabel('Tamaño del Dataset')
plt.ylabel('Tiempo de Ejecución (ms)')
plt.ylim([0, 10000])    #Cambiar limites del eje y
plt.legend()
plt.grid(True)

plt.savefig('graficos\orden_dat_inv_ord.png')

# Mostrar el gráfico
plt.show()
# Out:
#    Tamaño  Selection Sort  Merge Sort  Quick Sort  std::sort
# 0   10000              51           2           8          0
# 1  100000            4618          28          83          6
# 2  200000           18670          54         149         14
# 3  300000           41840          81         255         23
# 4  400000           74451         113         318         30

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Leer el archivo CSV
df = pd.read_csv('Datasets_Resultados/tiempos_ordenado.csv')

# Mostrar las primeras filas del DataFrame para verificar que los datos se leyeron correctamente
print(df.head())

# Extraer los datos del CSV
tamanios = df['Tamaño']
selection_sort = df['Selection Sort']
merge_sort = df['Merge Sort']
quick_sort = df['Quick Sort']
std_sort = df['std::sort']

# Crear las curvas teóricas n^2 y n log n
n = np.array(tamanios)
n_squared = n ** 2
n_log_n = n * np.log2(n)

# Crear el gráfico
plt.figure(figsize=(10, 6))

plt.plot(tamanios, selection_sort, label='Selection Sort', marker='o')
plt.plot(tamanios, merge_sort, label='Merge Sort', marker='o')
plt.plot(tamanios, quick_sort, label='Quick Sort', marker='o')
plt.plot(tamanios, std_sort, label='std::sort', marker='o')


# Graficar las curvas teóricas
plt.plot(n, n_squared / max(n_squared) * max(selection_sort), label='$n^2$', linestyle='--', color='purple')
plt.plot(n, n_log_n / max(n_log_n) * max(merge_sort), label='$n \log n$', linestyle='--', color='pink')


# Configuración del gráfico
plt.title('Comparación de Algoritmos de Ordenamiento con datos ordenado')
plt.xlabel('Tamaño del Dataset')
plt.ylabel('Tiempo de Ejecución (ms)')
plt.ylim([0, 10000])    #Cambiar limites del eje y
plt.legend()
plt.grid(True)

plt.savefig('graficos\orden_dat_ord.png')

# Mostrar el gráfico
plt.show()
# Out:
#    Tamaño  Selection Sort  Merge Sort  Quick Sort  std::sort
# 0   10000              49           2           6          0
# 1  100000            4474          26          85          8
# 2  200000           17892          56         121         19
# 3  300000           40347          89         192         25
# 4  400000           72002         109         316         35

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Leer el archivo CSV
df = pd.read_csv('Datasets_Resultados/tiempos_repetido.csv')

# Mostrar las primeras filas del DataFrame para verificar que los datos se leyeron correctamente
print(df.head())

# Extraer los datos del CSV
tamanios = df['Tamaño']
selection_sort = df['Selection Sort']
merge_sort = df['Merge Sort']
quick_sort = df['Quick Sort']
std_sort = df['std::sort']

# Crear las curvas teóricas n^2 y n log n
n = np.array(tamanios)
n_squared = n ** 2
n_log_n = n * np.log2(n)

# Crear el gráfico
plt.figure(figsize=(10, 6))
plt.plot(tamanios, selection_sort, label='Selection Sort', marker='o')
plt.plot(tamanios, merge_sort, label='Merge Sort', marker='o')
plt.plot(tamanios, quick_sort, label='Quick Sort', marker='o')
plt.plot(tamanios, std_sort, label='std::sort', marker='o')

# Graficar las curvas teóricas
plt.plot(n, n_squared / max(n_squared) * max(selection_sort), label='$n^2$', linestyle='--', color='purple')
plt.plot(n, n_log_n / max(n_log_n) * max(merge_sort), label='$n \log n$', linestyle='--', color='pink')


# Configuración del gráfico
plt.title('Comparación de Algoritmos de Ordenamiento con datos repetidos')
plt.xlabel('Tamaño del Dataset')
plt.ylabel('Tiempo de Ejecución (ms)')
plt.ylim([0, 10000])
plt.legend()
plt.grid(True)

plt.savefig('graficos\orden_dat_rep.png')

# Mostrar el gráfico
plt.show()
# Out:
#    Tamaño  Selection Sort  Merge Sort  Quick Sort  std::sort
# 0   10000              49           3          10          1
# 1  100000            4414          33         145         16
# 2  200000           17728          69         359         33
# 3  300000           40027         109         628         49
# 4  400000           70889         146         959         69
